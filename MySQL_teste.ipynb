# %%
from sqlalchemy import create_engine
import mysql.connector
import pandas as pd
#engine = create_engine("mysql:///?User=root&;Password=123456&Database=teste_db&Server=localhost&Port=3306")

engine = create_engine("mysql+pymysql://root:123456@localhost:3306/leitura_contrato",)

# %%
conn = mysql.connector.connect(user='root', password='123456', host='localhost')

cursor = conn.cursor()

cursor.execute("SHOW DATABASES")
print(cursor.fetchall())


# data = cursor.fetchone()
# print("Connection established to: ",data)
# Out:
# [('information_schema',), ('leitura_contrato',), ('leituras',), ('mysql',), ('performance_schema',), ('sakila',), ('sys',), ('teste1',), ('teste_db',), ('world',)]

# %%
df.to_sql('users', con=engine)
engine.execute("SELECT * FROM users").fetchall()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MANUEL~1.CAB\AppData\Local\Temp/ipykernel_4120/3450791805.py in <module>
# ----> 1 df.to_sql('users', con=engine)
#       2 engine.execute("SELECT * FROM users").fetchall()
#
# NameError: name 'df' is not defined

# %%
with engine.begin() as connection:
    df1 = pd.DataFrame({'name' : ['User 4', 'User 5']})
    df1.to_sql('users', con=connection, if_exists='append')

# %%
engine.execute("SELECT * FROM users").fetchall()
# Out:
# [(0, 'User 1'), (1, 'User 2'), (2, 'User 3'), (0, 'User 4'), (1, 'User 5')]

# %%
df1.to_sql('users', con=engine, if_exists='replace',
           index_label='id')
engine.execute("SELECT * FROM users").fetchall()
# Out:
# [(0, 'User 4'), (1, 'User 5')]

# %%
engine.execute("SELECT * FROM users").fetchall()
# Out:
# [(0, 'User 4'), (1, 'User 5')]

# %%
dados = pd.read_pickle('included_selection_df.pkl')
dados.to_csv('incluidas.csv')

# %%
dados.to_sql('incluidas', con = engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\MANUEL~1.CAB\AppData\Local\Temp/ipykernel_12320/1654112978.py in <module>
# ----> 1 dados.to_sql('incluidas', con = engine)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ...

# %%
engine.execute('select * from incluidas').fetchall()
# Out:
# [(4, 'TIBAGI ENERGIA SPE S.A., sociedade por ações de capital fechado, com sede na Cidade de Belo Horizonte, Estado de Minas Gerais, na Avenida Getúlio Var ... (261 characters truncated) ... resentante(s) legal(is) devidamente autorizado(s) e identificado(s) nas páginas de assinaturas do presente instrumento (“Emissora” ou “Companhia”); e', 1),
#  (18, 'A presente Escritura de Emissão e os Contratos de Garantia (conforme definido na Cláusula 4.15.1 abaixo) são firmados pela Emissora com base nas deli ... (1277 characters truncated) ... entos até então assinados pela diretoria da Emissora para a implementação da Oferta Restrita, da Emissão e da constituição das garantias necessárias.', 1),
# ...

# %%
all_dados  = pd.read_pickle('included_df.pkl')

# %%
all_dados.to_sql('all_dados', con = engine)

# %%
engine.execute('select * from all_dados').fetchall()
# Out:
# [(0, 'INSTRUMENTO PARTICULAR DE ESCRITURA DA 1ª (PRIMEIRA) EMISSÃO DE DEBÊNTURES SIMPLES, NÃO CONVERSÍVEIS EM AÇÕES, DA ESPÉCIE COM GARANTIA REAL, COM GARANTIA ADICIONAL FIDEJUSSÓRIA, EM SÉRIE ÚNICA, PARA DISTRIBUIÇÃO PÚBLICA COM ESFORÇOS RESTRITOS, DA TIBAGI ENERGIA SPE S.A. ', 0),
#  (1, '', 0),
#  (2, 'Pelo presente instrumento,', 0),
#  (3, '', 0),
#  (4, 'TIBAGI ENERGIA SPE S.A., sociedade por ações de capital fechado, com sede na Cidade de Belo Horizonte, Estado de Minas Gerais, na Avenida Getúlio Var ... (261 characters truncated) ... resentante(s) legal(is) devidamente autorizado(s) e identificado(s) nas páginas de assinaturas do presente instrumento (“Emissora” ou “Companhia”); e', 1),
#  (5, '', 0),
# ...

# %%
import uuid

# %%
uuid.UUID('bd65600d-8669-4903-8a14-af88203add38')
# Out:
# UUID('bd65600d-8669-4903-8a14-af88203add38')

# %%
uuid.uuid4()
# Out:
# UUID('a14a8028-09a3-4557-9a84-1175ed41b154')

# %%
'1272 1637 5356 51'
